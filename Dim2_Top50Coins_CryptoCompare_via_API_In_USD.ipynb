# %% [markdown]
# <a href="https://colab.research.google.com/github/SinghPrach/AeroCoding/blob/main/Dim2_Top50Coins_CryptoCompare_via_API_In_USD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# drive.flush_and_unmount()
# Out:
# Mounted at /content/drive

# %%
from datetime import datetime
import pandas as pd
import pyarrow as pa
import pyarrow.parquet as pq

# %%
now = datetime.now()
current_month_name = now.strftime('%B')
current_year = now.year
current_year_str = str(current_year)
curr_month_year = current_month_name + current_year_str
day = str(now.day)
current_month = current_month_name[:3]

# %%
print(current_month)
# Out:
# Jan

# %%
day_var = day+'_'+curr_month_year

# %%
print(day_var)
# Out:
# 15_January2025

# %%
import os
# os.listdir('/content/drive/MyDrive/')

# %%
# CryptoCompareAPI
api_key = '4ee7e5e8c398899805db332782c42e149ffc2d0634e3c1f6bf29e78d179a6cb5' #cam.iphone

# %%
import requests
import time

# %%
# Endpoint to get the list of all available cryptocurrencies
url = "https://min-api.cryptocompare.com/data/all/coinlist"

params = {
    'api_key': api_key
}

# Send the request to the CryptoCompare API
response = requests.get(url, params=params)

# %%
if response.status_code == 200:
    coins = response.json()['Data']

    # Filter active coins (where IsTrading == True)
    active_coins = [coin for coin in coins.values() if coin['IsTrading']] # list

    # Sort the active coins based on TotalCoinsSupply (in descending order)
    sorted_coins = sorted(active_coins, key=lambda x: x['TotalCoinsMined'] if x.get('TotalCoinsMined') else 0, reverse=True)

# %%
df_sortedcoins = pd.DataFrame(sorted_coins)

# %%
top_50_coins = df_sortedcoins.sort_values(by='TotalCoinsMined', ascending=False).head(50)
df_top_50_coins = top_50_coins[['Symbol','FullName','TotalCoinsMined']]

# %%
df_top_50_coins['ScientificNotation_TotalCoinsMined'] = df_top_50_coins['TotalCoinsMined'].apply(lambda x: '{:e}'.format(x))
# Out:
# <ipython-input-14-15a32584f9c4>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_top_50_coins['ScientificNotation_TotalCoinsMined'] = df_top_50_coins['TotalCoinsMined'].apply(lambda x: '{:e}'.format(x))

# %%
print(df_top_50_coins['TotalCoinsMined'].dtype)
# Out:
# object

# %%
df_top_50_coins['Timestamp'] = datetime.now().strftime('%Y-%m-%d %H:%M:%S')
# Out:
# <ipython-input-16-23e75c30f6e3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_top_50_coins['Timestamp'] = datetime.now().strftime('%Y-%m-%d %H:%M:%S')

# %%
df_save = df_top_50_coins[['Symbol','FullName','ScientificNotation_TotalCoinsMined','Timestamp']]

# %%
drive_folder = '/content/drive/My Drive/mycolab_container/Top50Coins/'+current_year_str+'/'+current_month+'/'+day+'/'

# %%
os.makedirs(drive_folder, exist_ok=True)

# %%
# df_top_50_coins['TotalCoinsMined'] = df_top_50_coins['TotalCoinsMined'].astype(pd.Int64Dtype())

# %%
parquet_file_path = os.path.join(drive_folder, 'crypto_data.parquet')
df_save.to_parquet(parquet_file_path, engine='pyarrow')

# %%
parquet_file_path = drive_folder+'crypto_data.parquet'

# Read the Parquet file into a DataFrame
df = pd.read_parquet(parquet_file_path, engine='pyarrow')

# %%
display(df)
# Out:
#          Symbol                                           FullName  \
# 0          MODA                                    MODA DAO (MODA)
# 1      SHIBDOGE                               ShibaDoge (SHIBDOGE)
# 2         4CHAN                                      4Chan (4CHAN)
# 3          ETHM                               Ethereum Meta (ETHM)
# 4     SHIRYOINU                             Shiryo-Inu (SHIRYOINU)
# 5   MONONOKEINU                         Mononoke Inu (MONONOKEINU)
# 6       POKEMON                                  Pokemon (POKEMON)
# 7      BABYGROK                               Baby Grok (BABYGROK)
# 8       DOGECEO                                 Doge CEO (DOGECEO)
# 9        BABYME                            Baby Meme Coin (BABYME)
# 10     BABYDOGE                                BabyDoge (BABYDOGE)
# 11       AIDOGE                                ArbDoge AI (AIDOGE)
# 12          PIT                                      Pitbull (PIT)
# 13        QUACK                                 Rich Quack (QUACK)
# 14          MOM                              Mother of Memes (MOM)
# 15         KLEE                                     KleeKai (KLEE)
# 16        KISHU                                  Kishu Inu (KISHU)
# 17          FWC                                   Qatar 2022 (FWC)
# 18         ADOG                                 America Dog (ADOG)
# 19         PEGA                                        PEGA (PEGA)
# 20    SAITAMAV1                             Saitama v1 (SAITAMAV1)
# 21       BEZOGE                              Bezoge Earth (BEZOGE)
# 22       SANSHU                                Sanshu Inu (SANSHU)
# 23      CATGIRL                                  Catgirl (CATGIRL)
# 24       NFTART                           NFT Art Finance (NFTART)
# 25          RET                             Renewable Energy (RET)
# 26    CATCOINV2                           CatCoin Cash (CATCOINV2)
# 27       TERAV1                               Terareum v1 (TERAV1)
# 28      CATCOIN                                  CatCoin (CATCOIN)
# 29          HAM                                      Hamster (HAM)
# 30       AIXERC                                      AI-X (AIXERC)
# 31          ASS                     Australian Safe Shepherd (ASS)
# 32     MCONTENT                                MContent (MCONTENT)
# 33       BABYTK                           Baby Tiger King (BABYTK)
# 34         SATS                             SATS (Ordinals) (SATS)
# 35         MMIT                        MangoMan Intelligent (MMIT)
# 36      SPACEPI                                  SpacePi (SPACEPI)
# 37          HYC                                        HYCON (HYC)
# 38        HOSKY                                      Hosky (HOSKY)
# 44         SPXC                                  SpaceXCoin (SPXC)
# 47        SHIRO                                 Shiro Neko (SHIRO)
# 46          PAW                                      PAWSWAP (PAW)
# 45        OMNOM                              Doge Eat Doge (OMNOM)
# 39         ELON                                Dogelon Mars (ELON)
# 43    SQUIDGROW                              SquidGrow (SQUIDGROW)
# 42         DCIP  Decentralized Community Investment Protocol (D...
# 41       NYANTE                  Nyantereum International (NYANTE)
# 40    BABYFLOKI                              BabyFloki (BABYFLOKI)
# 48          QOM                               Shiba Predator (QOM)
# 49          NFT                                       APENFT (NFT)
#
